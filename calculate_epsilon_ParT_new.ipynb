# %% [markdown]
# # Find a suiting epsilon
#
# The goal of this notebook is to derive a suitable magnitude of the attack for each feature.

# %%
#import uproot
import uproot4 as uproot
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
#import seaborn as sns
import mplhep as hep

# %%
import awkward1 as ak

# %%
uproot.__version__
# Out:
# '0.1.2'

# %% [markdown]
# ## Checking files content

# %% [markdown]
# Focusing on pred_ntuple_merged_342

# %%
NOMINAL_INPUT_FILE = "/eos/user/a/anstein/public/DeepJet/Train_DF/nominal_with_etarel_phirel/predict_FGSM/pred_ntuple_merged_342.root:tree"
ADVERSARIAL_INPUT_FILE = "/eos/user/a/anstein/public/DeepJet/Train_DF/adversarial_with_etarel_phirel/predict_FGSM/pred_ntuple_merged_342.root:tree"

# %%
inputs_root = "/eos/cms/store/group/phys_btag/ParT_Run3/Merged_Puppi_v1/ntuple_merged_42.root:deepntuplizer/tree"

# %%
file_ = uproot.open(inputs_root)
columns_ = file_.keys()

# %%
columns_
# Out:
# ['n_sv',
#  'nsv',
#  'sv_pt',
#  'sv_eta',
#  'sv_phi',
#  'sv_e',
#  'sv_etarel',
#  'sv_phirel',
#  'sv_deltaR',
#  'sv_mass',
#  'sv_ntracks',
#  'sv_chi2',
#  'sv_ndf',
#  'sv_normchi2',
#  'sv_dxy',
#  'sv_dxyerr',
#  'sv_dxysig',
#  'sv_d3d',
#  'sv_d3derr',
#  'sv_d3dsig',
#  'sv_costhetasvpv',
#  'sv_enratio',
#  'n_gtracks',
#  'nGtracks',
#  'gtrack_pt',
#  'gtrack_eta',
#  'gtrack_phi',
#  'gtrack_mass',
#  'gtrack_dz',
#  'gtrack_dxy',
#  'gtrack_3D_ip',
#  'gtrack_3D_sip',
#  'gtrack_2D_ip',
#  'gtrack_2D_sip',
#  'gtrack_dR',
#  'gtrack_dist_neigh',
#  'gtrack_3D_TrackProbability',
#  'gtrack_2D_TrackProbability',
#  'gtrack_chi2reduced',
#  'gtrack_nPixelHits',
#  'gtrack_nHits',
#  'gtrack_jetAxisDistance',
#  'gtrack_jetAxisDlength',
#  'gtrack_PCAtrackFromPV',
#  'gtrack_dotProdTrack',
#  'gtrack_dotProdTrack2D',
#  'npv',
#  'rho',
#  'ntrueInt',
#  'event_no',
#  'jet_no',
#  'gen_pt',
#  'Delta_gen_pt',
#  'isB',
#  'isGBB',
#  'isBB',
#  'isLeptonicB',
#  'isLeptonicB_C',
#  'isC',
#  'isGCC',
#  'isCC',
#  'isUD',
#  'isS',
#  'isG',
#  'isPU',
#  'isUndefined',
#  'genDecay',
#  'jet_hflav',
#  'jet_pflav',
#  'jet_phflav',
#  'jet_pt',
#  'jet_corr_pt',
#  'jet_eta',
#  'jet_phi',
#  'jet_mass',
#  'jet_energy',
#  'jet_looseId',
#  'jet_jetId',
#  'jet_puId',
#  'jet_qgl',
#  'QG_ptD',
#  'QG_axis2',
#  'QG_mult',
#  'gen_pt_Recluster',
#  'gen_pt_WithNu',
#  'Delta_gen_pt_Recluster',
#  'Delta_gen_pt_WithNu',
#  'pfCombinedInclusiveSecondaryVertexV2BJetTags',
#  'pfCombinedMVAV2BJetTags',
#  'pfDeepCSVJetTags_probb',
#  'pfDeepCSVJetTags_probbb',
#  'pfDeepCSVJetTags_probc',
#  'pfDeepCSVJetTags_probudsg',
#  'pfDeepFlavourJetTags_probb',
#  'pfDeepFlavourJetTags_probbb',
#  'pfDeepFlavourJetTags_probc',
#  'pfDeepFlavourJetTags_probg',
#  'pfDeepFlavourJetTags_problepb',
#  'pfDeepFlavourJetTags_probuds',
#  'pfJetBProbabilityBJetTags',
#  'pfJetProbabilityBJetTags',
#  'pfParticleNetAK4JetTags_probb',
#  'pfParticleNetAK4JetTags_probbb',
#  'pfParticleNetAK4JetTags_probc',
#  'pfParticleNetAK4JetTags_probcc',
#  'pfParticleNetAK4JetTags_probg',
#  'pfParticleNetAK4JetTags_probuds',
#  'softPFElectronBJetTags',
#  'softPFMuonBJetTags',
#  'n_Cpfcand',
#  'nCpfcand',
#  'Cpfcan_pt',
#  'Cpfcan_eta',
#  'Cpfcan_phi',
#  'Cpfcan_ptrel',
#  'Cpfcan_e',
#  'Cpfcan_erel',
#  'Cpfcan_phirel',
#  'Cpfcan_etarel',
#  'Cpfcan_deltaR',
#  'Cpfcan_puppiw',
#  'Cpfcan_dxy',
#  'Cpfcan_dxyerrinv',
#  'Cpfcan_dxysig',
#  'Cpfcan_dz',
#  'Cpfcan_VTX_ass',
#  'Cpfcan_fromPV',
#  'Cpfcan_drminsv',
#  'Cpfcan_distminsv',
#  'Cpfcan_dxminsv',
#  'Cpfcan_dyminsv',
#  'Cpfcan_dzminsv',
#  'Cpfcan_dxpv',
#  'Cpfcan_dypv',
#  'Cpfcan_dzpv',
#  'Cpfcan_vertex_rho',
#  'Cpfcan_vertex_phirel',
#  'Cpfcan_vertex_etarel',
#  'Cpfcan_BtagPf_trackMomentum',
#  'Cpfcan_BtagPf_trackEta',
#  'Cpfcan_BtagPf_trackEtaRel',
#  'Cpfcan_BtagPf_trackPtRel',
#  'Cpfcan_BtagPf_trackPPar',
#  'Cpfcan_BtagPf_trackDeltaR',
#  'Cpfcan_BtagPf_trackPtRatio',
#  'Cpfcan_BtagPf_trackPParRatio',
#  'Cpfcan_BtagPf_trackSip3dVal',
#  'Cpfcan_BtagPf_trackSip3dSig',
#  'Cpfcan_BtagPf_trackSip2dVal',
#  'Cpfcan_BtagPf_trackSip2dSig',
#  'Cpfcan_BtagPf_trackDecayLen',
#  'Cpfcan_BtagPf_trackJetDistVal',
#  'Cpfcan_BtagPf_trackJetDistSig',
#  'Cpfcan_isMu',
#  'Cpfcan_isEl',
#  'Cpfcan_charge',
#  'Cpfcan_lostInnerHits',
#  'Cpfcan_numberOfPixelHits',
#  'Cpfcan_chi2',
#  'Cpfcan_quality',
#  'Cpfcan_nhitpixelBarrelLayer1',
#  'Cpfcan_nhitpixelBarrelLayer2',
#  'Cpfcan_nhitpixelBarrelLayer3',
#  'Cpfcan_nhitpixelBarrelLayer4',
#  'Cpfcan_nhitpixelEndcapLayer1',
#  'Cpfcan_nhitpixelEndcapLayer2',
#  'Cpfcan_nhitstripTIBLayer1',
#  'Cpfcan_nhitstripTIBLayer2',
#  'Cpfcan_nhitstripTIBLayer3',
#  'Cpfcan_nhitstripTIBLayer4',
#  'Cpfcan_nhitstripTIDLayer1',
#  'Cpfcan_nhitstripTIDLayer2',
#  'Cpfcan_nhitstripTIDLayer3',
#  'Cpfcan_nhitstripTOBLayer1',
#  'Cpfcan_nhitstripTOBLayer2',
#  'Cpfcan_nhitstripTOBLayer3',
#  'Cpfcan_nhitstripTOBLayer4',
#  'Cpfcan_nhitstripTOBLayer5',
#  'Cpfcan_nhitstripTOBLayer6',
#  'Cpfcan_nhitstripTECLayer1',
#  'Cpfcan_nhitstripTECLayer2',
#  'Cpfcan_nhitstripTECLayer3',
#  'Cpfcan_nhitstripTECLayer4',
#  'Cpfcan_nhitstripTECLayer5',
#  'Cpfcan_nhitstripTECLayer6',
#  'Cpfcan_nhitstripTECLayer7',
#  'Cpfcan_nhitstripTECLayer8',
#  'Cpfcan_nhitstripTECLayer9',
#  'Cpfcan_numberOfValidHits',
#  'Cpfcan_numberOfValidTrackerHits',
#  'Cpfcan_numberOfValidPixelHits',
#  'Cpfcan_numberOfValidPixelBarrelHits',
#  'Cpfcan_numberOfValidPixelEndcapHits',
#  'Cpfcan_numberOfValidStripHits',
#  'Cpfcan_numberOfValidStripTIBHits',
#  'Cpfcan_numberOfValidStripTIDHits',
#  'Cpfcan_numberOfValidStripTOBHits',
#  'Cpfcan_numberOfValidStripTECHits',
#  'Cpfcan_trackerLayersWithMeasurementOld',
#  'Cpfcan_trackerLayersWithMeasurement',
#  'Cpfcan_pixelLayersWithMeasurementOld',
#  'Cpfcan_pixelLayersWithMeasurement',
#  'Cpfcan_stripLayersWithMeasurement',
#  'Cpfcan_pixelBarrelLayersWithMeasurement',
#  'Cpfcan_pixelEndcapLayersWithMeasurement',
#  'Cpfcan_stripTIBLayersWithMeasurement',
#  'Cpfcan_stripTIDLayersWithMeasurement',
#  'Cpfcan_stripTOBLayersWithMeasurement',
#  'Cpfcan_stripTECLayersWithMeasurement',
#  'Cpfcan_trackerLayersNull',
#  'Cpfcan_pixelLayersNull',
#  'Cpfcan_stripLayersNull',
#  'Cpfcan_pixelBarrelLayersNull',
#  'Cpfcan_pixelEndcapLayersNull',
#  'Cpfcan_stripTIBLayersNull',
#  'Cpfcan_stripTIDLayersNull',
#  'Cpfcan_stripTOBLayersNull',
#  'Cpfcan_stripTECLayersNull',
#  'n_Npfcand',
#  'nNpfcand',
#  'Npfcan_pt',
#  'Npfcan_eta',
#  'Npfcan_phi',
#  'Npfcan_ptrel',
#  'Npfcan_e',
#  'Npfcan_erel',
#  'Npfcan_puppiw',
#  'Npfcan_phirel',
#  'Npfcan_etarel',
#  'Npfcan_deltaR',
#  'Npfcan_isGamma',
#  'Npfcan_HadFrac',
#  'Npfcan_drminsv',
#  'trackJetPt',
#  'jetNTracks',
#  'TagVarCSV_jetNSecondaryVertices',
#  'TagVarCSV_trackSumJetEtRatio',
#  'TagVarCSV_trackSumJetDeltaR',
#  'TagVarCSV_vertexCategory',
#  'TagVarCSV_trackSip2dValAboveCharm',
#  'TagVarCSV_trackSip2dSigAboveCharm',
#  'TagVarCSV_trackSip3dValAboveCharm',
#  'TagVarCSV_trackSip3dSigAboveCharm',
#  'n_TagVarCSV_jetNSelectedTracks',
#  'TagVarCSV_jetNSelectedTracks',
#  'TagVarCSVTrk_trackPtRel',
#  'TagVarCSVTrk_trackDeltaR',
#  'TagVarCSVTrk_trackPtRatio',
#  'TagVarCSVTrk_trackSip3dSig',
#  'TagVarCSVTrk_trackSip2dSig',
#  'TagVarCSVTrk_trackDecayLenVal',
#  'TagVarCSVTrk_trackJetDistVal',
#  'n_TagVarCSV_jetNTracksEtaRel',
#  'TagVarCSV_jetNTracksEtaRel',
#  'TagVarCSV_trackEtaRel',
#  'trackPParRatio',
#  'trackSip2dVal',
#  'trackSip3dVal',
#  'trackMomentum',
#  'trackEta',
#  'trackPPar',
#  'n_StoredVertices',
#  'NStoredVertices',
#  'TagVarCSV_vertexMass',
#  'TagVarCSV_vertexNTracks',
#  'TagVarCSV_vertexEnergyRatio',
#  'TagVarCSV_vertexJetDeltaR',
#  'TagVarCSV_flightDistance2dVal',
#  'TagVarCSV_flightDistance2dSig',
#  'TagVarCSV_flightDistance3dVal',
#  'TagVarCSV_flightDistance3dSig']

# %%
global_branches = ['jet_pt', 'jet_eta',
                    'nCpfcand','nNpfcand',
                    'nsv','npv',
                    'TagVarCSV_trackSumJetEtRatio',
                    'TagVarCSV_trackSumJetDeltaR',
                    'TagVarCSV_vertexCategory',
                    'TagVarCSV_trackSip2dValAboveCharm',
                    'TagVarCSV_trackSip2dSigAboveCharm',
                    'TagVarCSV_trackSip3dValAboveCharm',
                    'TagVarCSV_trackSip3dSigAboveCharm',
                    'TagVarCSV_jetNSelectedTracks',
                    'TagVarCSV_jetNTracksEtaRel']
cpf_branches = ['Cpfcan_BtagPf_trackEtaRel',
                 'Cpfcan_BtagPf_trackPtRel',
                 'Cpfcan_BtagPf_trackPPar',
                 'Cpfcan_BtagPf_trackDeltaR',
                 'Cpfcan_BtagPf_trackPParRatio',
                 'Cpfcan_BtagPf_trackSip2dVal',
                 'Cpfcan_BtagPf_trackSip2dSig',
                 'Cpfcan_BtagPf_trackSip3dVal',
                 'Cpfcan_BtagPf_trackSip3dSig',
                 'Cpfcan_BtagPf_trackJetDistVal',
                 'Cpfcan_ptrel',
                 'Cpfcan_drminsv',
                 'Cpfcan_VTX_ass',
                 'Cpfcan_puppiw',
                 'Cpfcan_chi2',
                 'Cpfcan_quality']
npf_branches = ['Npfcan_ptrel', 
                 #'Npfcan_etarel', 'Npfcan_phirel',
                 'Npfcan_deltaR',
                 'Npfcan_isGamma', 'Npfcan_HadFrac', 'Npfcan_drminsv', 'Npfcan_puppiw']
vtx_branches = ['sv_pt','sv_deltaR',
                 'sv_mass',
                 #'sv_etarel',
                 #'sv_phirel',
                 'sv_ntracks',
                 'sv_chi2',
                 'sv_normchi2',
                 'sv_dxy',
                 'sv_dxysig',
                 'sv_d3d',
                 'sv_d3dsig',
                 'sv_costhetasvpv',
                 'sv_enratio']

# %%
df_glob = file_.arrays(global_branches, library="ak")

# %%
df_cpf = file_.arrays(cpf_branches, library="ak")

# %%
df_npf = file_.arrays(npf_branches, library="ak")

# %%
df_vtx = file_.arrays(vtx_branches, library="ak")

# %%
df_glob
# Out:
# <Array [{jet_pt: 24.3, ... ] type='400000 * {"jet_pt": float32, "jet_eta": float...'>

# %%
df_cpf
# Out:
# <Array [{Cpfcan_BtagPf_trackEtaRel: [, ... ] type='400000 * {"Cpfcan_BtagPf_trac...'>

# %%
df_npf
# Out:
# <Array [{Npfcan_ptrel: [-0.918, ... 0.969]}] type='400000 * {"Npfcan_ptrel": var...'>

# %%
df_vtx
# Out:
# <Array [{sv_pt: [], ... sv_enratio: []}] type='400000 * {"sv_pt": var * float32,...'>

# %%
df_cpf_clip = ak.pad_none(df_cpf,25,clip=True)

# %%
df_npf_clip = ak.pad_none(df_npf,25,clip=True)

# %%
df_vtx_clip = ak.pad_none(df_vtx,4,clip=True)

# %%
df_vtx_clip.type
# Out:
# 400000 * {"sv_pt": 4 * ?float32, "sv_deltaR": 4 * ?float32, "sv_mass": 4 * ?float32, "sv_ntracks": 4 * ?float32, "sv_chi2": 4 * ?float32, "sv_normchi2": 4 * ?float32, "sv_dxy": 4 * ?float32, "sv_dxysig": 4 * ?float32, "sv_d3d": 4 * ?float32, "sv_d3dsig": 4 * ?float32, "sv_costhetasvpv": 4 * ?float32, "sv_enratio": 4 * ?float32}

# %%
def quantile_min_max(feature,group='glob',candidate=None):
    if group=='glob':
        print(feature,group,candidate)
        array_np = ak.to_numpy(df_glob[feature])
        array_np = np.where(array_np == -999, 0, array_np)
        array_np = np.where(array_np ==   -1, 0, array_np)
        return [np.quantile(array_np,0.005),np.quantile(array_np,0.995)]
    elif group=='cpf':
        print(feature,group,candidate)
        array_np = ak.to_numpy(df_cpf_clip[feature][:,candidate])
        array_np = np.where(array_np == -999, 0, array_np)
        array_np = np.where(array_np ==   -1, 0, array_np)
        return [np.quantile(array_np,0.005),np.quantile(array_np,0.995)]
    elif group=='npf':
        print(feature,group,candidate)
        array_np = ak.to_numpy(df_npf_clip[feature][:,candidate])
        array_np = np.where(array_np == -999, 0, array_np)
        array_np = np.where(array_np ==   -1, 0, array_np)
        return [np.quantile(array_np,0.005),np.quantile(array_np,0.995)]
    elif group=='vtx':
        print(feature,group,candidate)
        array_np = ak.to_numpy(df_vtx_clip[feature][:,candidate])
        #print(array_np)
        array_np = np.where(array_np == -999, 0, array_np)
        array_np = np.where(array_np ==   -1, 0, array_np)
        return [np.quantile(array_np,0.005),np.quantile(array_np,0.995)]

# %%
print(quantile_min_max('jet_pt','glob'))
# Out:
# jet_pt glob None
# [14.954755067825317, 1700.1684771728524]

# %%
print(quantile_min_max('Cpfcan_BtagPf_trackEtaRel','cpf',1))
# Out:
# Cpfcan_BtagPf_trackEtaRel cpf 1
# [1.6659805768728257, 456.2992126464855]

# %%
global_epsilons = np.zeros(len(global_branches))

# %%
global_ranges = np.zeros((len(global_branches),2))

# %%
for (i,key) in enumerate(global_branches):
    range_inputs = quantile_min_max(key,'glob')
    scale_epsilon = (range_inputs[1] - range_inputs[0])/2
    global_epsilons[i] = scale_epsilon
    global_ranges[i] = range_inputs
    print(range_inputs, scale_epsilon)
# Out:
# jet_pt glob None
# [14.954755067825317, 1700.1684771728524] 842.6068610525135
# jet_eta glob None
# [-2.4466045618057253, 2.4464884662628177] 2.4465465140342717
# nCpfcand glob None
# [0.0, 40.0] 20.0
# nNpfcand glob None
# [0.0, 22.0] 11.0
# nsv glob None
# [0.0, 5.0] 2.5
# npv glob None
# [7.0, 51.0] 22.0
# TagVarCSV_trackSumJetEtRatio glob None
# [0.0, 1.2057606065273305] 0.6028803032636653
# TagVarCSV_trackSumJetDeltaR glob None
# [0.0, 3.068409718275071] 1.5342048591375355
# TagVarCSV_vertexCategory glob None
# [0.0, 2.0] 1.0
# TagVarCSV_trackSip2dValAboveCharm glob None
# [-0.023457033559679985, 0.05388612478971518] 0.03867157917469759
# TagVarCSV_trackSip2dSigAboveCharm glob None
# [-4.50480307340622, 18.87342078208925] 11.689111927747735
# TagVarCSV_trackSip3dValAboveCharm glob None
# [-0.05840983817353844, 0.08670980717986829] 0.07255982267670336
# TagVarCSV_trackSip3dSigAboveCharm glob None
# [-10.18956787586212, 26.20179145812989] 18.195679666996007
# TagVarCSV_jetNSelectedTracks glob None
# [0.0, 19.0] 9.5
# TagVarCSV_jetNTracksEtaRel glob None
# [0.0, 11.0] 5.5

# %%
global_ranges
# Out:
# array([[ 1.49547551e+01,  1.70016848e+03],
#        [-2.44660456e+00,  2.44648847e+00],
#        [ 0.00000000e+00,  4.00000000e+01],
#        [ 0.00000000e+00,  2.20000000e+01],
#        [ 0.00000000e+00,  5.00000000e+00],
#        [ 7.00000000e+00,  5.10000000e+01],
#        [ 0.00000000e+00,  1.20576061e+00],
#        [ 0.00000000e+00,  3.06840972e+00],
#        [ 0.00000000e+00,  2.00000000e+00],
#        [-2.34570336e-02,  5.38861248e-02],
#        [-4.50480307e+00,  1.88734208e+01],
#        [-5.84098382e-02,  8.67098072e-02],
#        [-1.01895679e+01,  2.62017915e+01],
#        [ 0.00000000e+00,  1.90000000e+01],
#        [ 0.00000000e+00,  1.10000000e+01]])

# %%
cpf_epsilons = np.zeros((len(cpf_branches),25))

# %%
cpf_ranges = np.zeros((len(cpf_branches),25, 2))

# %%
for (i,key) in enumerate(cpf_branches):
    for cand in range(25):
        range_inputs = quantile_min_max(key,'cpf',cand)
        scale_epsilon = (range_inputs[1] - range_inputs[0])/2
# [-0.3977421522140503, 4.5785214181083766e-39] 0.19887107610702515
# Cpfcan_drminsv cpf 15
# [-0.3978384166955948, 4.5785214181083766e-39] 0.1989192083477974
# Cpfcan_drminsv cpf 16
# [-0.39782667651772496, 4.5785214181083766e-39] 0.19891333825886248
# Cpfcan_drminsv cpf 17
# [-0.3978876809775829, 4.5785214181083766e-39] 0.19894384048879146
# Cpfcan_drminsv cpf 18
# [-0.39791715189814564, 4.5785214181083766e-39] 0.19895857594907282
# Cpfcan_drminsv cpf 19
# [-0.39794260457158087, 4.5785214181083766e-39] 0.19897130228579044
# Cpfcan_drminsv cpf 20
# [-0.39797495141625405, 4.5785214181083766e-39] 0.19898747570812703
# Cpfcan_drminsv cpf 21
# [-0.397977591753006, 4.5785214181083766e-39] 0.198988795876503
# Cpfcan_drminsv cpf 22
# [-0.39800143778324126, 4.5785214181083766e-39] 0.19900071889162063
# Cpfcan_drminsv cpf 23
# [-0.3980180037021637, 4.5785214181083766e-39] 0.19900900185108186
# Cpfcan_drminsv cpf 24
# [-0.3980332048237324, 4.5785214181083766e-39] 0.1990166024118662
# Cpfcan_VTX_ass cpf 0
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 1
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 2
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 3
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 4
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 5
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 6
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 7
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 8
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 9
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 10
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 11
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 12
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 13
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 14
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 15
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 16
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 17
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 18
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 19
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 20
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 21
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 22
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 23
# [0.0, 7.0] 3.5
# Cpfcan_VTX_ass cpf 24
# [0.0, 7.0] 3.5
# Cpfcan_puppiw cpf 0
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 1
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 2
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 3
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 4
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 5
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 6
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 7
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 8
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 9
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 10
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 11
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 12
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 13
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 14
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 15
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 16
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 17
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 18
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 19
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 20
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 21
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 22
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 23
# [0.0, 1.0] 0.5
# Cpfcan_puppiw cpf 24
# [0.0, 1.0] 0.5
# Cpfcan_chi2 cpf 0
# [0.0, 41.0] 20.5
# Cpfcan_chi2 cpf 1
# [0.0, 39.0] 19.5
# Cpfcan_chi2 cpf 2
# [0.0, 34.0] 17.0
# Cpfcan_chi2 cpf 3
# [0.0, 32.0] 16.0
# Cpfcan_chi2 cpf 4
# [0.0, 33.0] 16.5
# Cpfcan_chi2 cpf 5
# [0.0, 34.0] 17.0
# Cpfcan_chi2 cpf 6
# [0.0, 11.0] 5.5
# Cpfcan_chi2 cpf 7
# [0.0, 13.0] 6.5
# Cpfcan_chi2 cpf 8
# [0.0, 16.0] 8.0
# Cpfcan_chi2 cpf 9
# [0.0, 18.0] 9.0
# Cpfcan_chi2 cpf 10
# [0.0, 20.0] 10.0
# Cpfcan_chi2 cpf 11
# [0.0, 22.0] 11.0
# Cpfcan_chi2 cpf 12
# [0.0, 24.0] 12.0
# Cpfcan_chi2 cpf 13
# [0.0, 27.0] 13.5
# Cpfcan_chi2 cpf 14
# [0.0, 28.0] 14.0
# Cpfcan_chi2 cpf 15
# [0.0, 30.0] 15.0
# Cpfcan_chi2 cpf 16
# [0.0, 31.0] 15.5
# Cpfcan_chi2 cpf 17
# [0.0, 32.0] 16.0
# Cpfcan_chi2 cpf 18
# [0.0, 33.0] 16.5
# Cpfcan_chi2 cpf 19
# [0.0, 34.0] 17.0
# Cpfcan_chi2 cpf 20
# [0.0, 35.0] 17.5
# Cpfcan_chi2 cpf 21
# [0.0, 35.0] 17.5
# Cpfcan_chi2 cpf 22
# [0.0, 36.0] 18.0
# Cpfcan_chi2 cpf 23
# [0.0, 37.0] 18.5
# Cpfcan_chi2 cpf 24
# [0.0, 37.0] 18.5
# Cpfcan_quality cpf 0
# [2.331570474421902e-39, 5.0] 2.5
# Cpfcan_quality cpf 1
# [2.331570474421902e-39, 5.0] 2.5
# Cpfcan_quality cpf 2
# [2.33137122379326e-39, 5.0] 2.5
# Cpfcan_quality cpf 3
# [2.3310779390311698e-39, 5.0] 2.5
# Cpfcan_quality cpf 4
# [2.3310779390311698e-39, 5.0] 2.5
# Cpfcan_quality cpf 5
# [2.3310779390311698e-39, 5.0] 2.5
# Cpfcan_quality cpf 6
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 7
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 8
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 9
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 10
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 11
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 12
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 13
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 14
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 15
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 16
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 17
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 18
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 19
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 20
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 21
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 22
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 23
# [0.0, 5.0] 2.5
# Cpfcan_quality cpf 24
# [0.0, 5.0] 2.5

# %%
npf_epsilons = np.zeros((len(npf_branches),25))

# %%
npf_ranges = np.zeros((len(npf_branches),25, 2))

# %%
for (i,key) in enumerate(npf_branches):
    for cand in range(25):
        range_inputs = quantile_min_max(key,'npf',cand)
        scale_epsilon = (range_inputs[1] - range_inputs[0])/2
        npf_epsilons[i,cand] = scale_epsilon
        npf_ranges[i,cand] = range_inputs
        print(range_inputs, scale_epsilon)
# Out:
# Npfcan_ptrel npf 0
# [-0.9976771494746208, 5.0] 2.9988385747373103
# Npfcan_ptrel npf 1
# [-0.9983924651145935, 5.0] 2.9991962325572965
# Npfcan_ptrel npf 2
# [-0.9988347306847573, 5.0] 2.999417365342379
# Npfcan_ptrel npf 3
# [-0.9989339128136635, 2.455066529732263e-39] 0.49946695640683175
# Npfcan_ptrel npf 4
# [-0.9989992380142212, 3.0566021317077466e-39] 0.4994996190071106
# Npfcan_ptrel npf 5
# [-0.9990548500418663, 3.0566021317077466e-39] 0.49952742502093317
# Npfcan_ptrel npf 6
# [-0.9991021165251732, 3.0566021317077466e-39] 0.4995510582625866
# Npfcan_ptrel npf 7
# [-0.9991229176521301, 3.0566021317077466e-39] 0.49956145882606506
# Npfcan_ptrel npf 8
# [-0.999152780175209, 3.0566021317077466e-39] 0.4995763900876045
# Npfcan_ptrel npf 9
# [-0.9991658931970596, 3.0566021317077466e-39] 0.4995829465985298
# Npfcan_ptrel npf 10
# [-0.9991778138279915, 3.0566021317077466e-39] 0.49958890691399577
# Npfcan_ptrel npf 11
# [-0.9991930726170539, 3.0566021317077466e-39] 0.49959653630852696
# Npfcan_ptrel npf 12
# [-0.9991957557201385, 3.0566021317077466e-39] 0.49959787786006926
# Npfcan_ptrel npf 13
# [-0.9992033252120018, 3.0566021317077466e-39] 0.4996016626060009
# Npfcan_ptrel npf 14
# [-0.9992072588205337, 3.05664985292695e-39] 0.49960362941026687
# Npfcan_ptrel npf 15
# [-0.9992122653126716, 3.05664985292695e-39] 0.4996061326563358
# Npfcan_ptrel npf 16
# [-0.9992156034708023, 3.05664985292695e-39] 0.49960780173540115
# Npfcan_ptrel npf 17
# [-0.9992163190245629, 3.05664985292695e-39] 0.49960815951228144
# Npfcan_ptrel npf 18
# [-0.9992188811302185, 3.05664985292695e-39] 0.49960944056510925
# Npfcan_ptrel npf 19
# [-0.9992204308509827, 3.05664985292695e-39] 0.49961021542549133
# Npfcan_ptrel npf 20
# [-0.9992207291722298, 3.05664985292695e-39] 0.4996103645861149
# Npfcan_ptrel npf 21
# [-0.9992207884788513, 3.05664985292695e-39] 0.49961039423942566
# Npfcan_ptrel npf 22
# [-0.9992207884788513, 3.05664985292695e-39] 0.49961039423942566
# Npfcan_ptrel npf 23
# [-0.99922114610672, 3.05664985292695e-39] 0.49961057305336
# Npfcan_ptrel npf 24
# [-0.99922114610672, 3.05664985292695e-39] 0.49961057305336
# Npfcan_deltaR npf 0
# [-0.5985857850313187, 2.150685971108724e-39] 0.2992928925156593
# Npfcan_deltaR npf 1
# [-0.5960316729545594, 2.150685971108724e-39] 0.2980158364772797
# Npfcan_deltaR npf 2
# [-0.5928099757432937, 2.1513262734225194e-39] 0.2964049878716469
# Npfcan_deltaR npf 3
# [-0.5860679787397385, 2.455066529732263e-39] 0.29303398936986924
# Npfcan_deltaR npf 4
# [-0.5802875870466232, 3.0566021317077466e-39] 0.2901437935233116
# Npfcan_deltaR npf 5
# [-0.574595676958561, 3.0566021317077466e-39] 0.2872978384792805
# Npfcan_deltaR npf 6
# [-0.5698158222436905, 3.0566021317077466e-39] 0.28490791112184527
# Npfcan_deltaR npf 7
# [-0.5669564092159272, 3.0566021317077466e-39] 0.2834782046079636
# Npfcan_deltaR npf 8
# [-0.5636926946043969, 3.0566021317077466e-39] 0.28184634730219843
# Npfcan_deltaR npf 9
# [-0.5618545645475388, 3.0566021317077466e-39] 0.2809272822737694
# Npfcan_deltaR npf 10
# [-0.5604026758670807, 3.0566021317077466e-39] 0.28020133793354035
# Npfcan_deltaR npf 11
# [-0.5594987189769745, 3.0566021317077466e-39] 0.2797493594884872
# Npfcan_deltaR npf 12
# [-0.5591382071375848, 3.0566021317077466e-39] 0.2795691035687924
# Npfcan_deltaR npf 13
# [-0.5588735440373421, 3.0566021317077466e-39] 0.27943677201867106
# Npfcan_deltaR npf 14
# [-0.5586134001612664, 3.05664985292695e-39] 0.2793067000806332
# Npfcan_deltaR npf 15
# [-0.5583931958675384, 3.05664985292695e-39] 0.2791965979337692
# Npfcan_deltaR npf 16
# [-0.5583829647302627, 3.05664985292695e-39] 0.27919148236513136
# Npfcan_deltaR npf 17
# [-0.5582869690656662, 3.05664985292695e-39] 0.2791434845328331
# Npfcan_deltaR npf 18
# [-0.5582130324840546, 3.05664985292695e-39] 0.2791065162420273
# Npfcan_deltaR npf 19
# [-0.5582206916809082, 3.05664985292695e-39] 0.2791103458404541
# Npfcan_deltaR npf 20
# [-0.5582340374588967, 3.05664985292695e-39] 0.27911701872944833
# Npfcan_deltaR npf 21
# [-0.5582130324840546, 3.05664985292695e-39] 0.2791065162420273
# Npfcan_deltaR npf 22
# [-0.5582128769159317, 3.05664985292695e-39] 0.27910643845796584
# Npfcan_deltaR npf 23
# [-0.5582128769159317, 3.05664985292695e-39] 0.27910643845796584
# Npfcan_deltaR npf 24
# [-0.5581869593262673, 3.05664985292695e-39] 0.27909347966313364
# Npfcan_isGamma npf 0
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 1
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 2
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 3
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 4
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 5
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 6
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 7
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 8
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 9
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 10
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 11
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 12
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 13
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 14
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 15
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 16
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 17
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 18
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 19
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 20
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 21
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 22
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 23
# [0.0, 1.0] 0.5
# Npfcan_isGamma npf 24
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 0
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 1
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 2
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 3
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 4
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 5
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 6
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 7
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 8
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 9
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 10
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 11
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 12
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 13
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 14
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 15
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 16
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 17
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 18
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 19
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 20
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 21
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 22
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 23
# [0.0, 1.0] 0.5
# Npfcan_HadFrac npf 24
# [0.0, 1.0] 0.5
# Npfcan_drminsv npf 0
# [-0.3983330449461937, 2.150685971108724e-39] 0.19916652247309685
# Npfcan_drminsv npf 1
# [-0.3921043774485588, 2.150685971108724e-39] 0.1960521887242794
# Npfcan_drminsv npf 2
# [-0.3777106936275959, 2.1513262734225194e-39] 0.18885534681379795
# Npfcan_drminsv npf 3
# [-0.3657533892989159, 2.455066529732263e-39] 0.18287669464945794
# Npfcan_drminsv npf 4
# [-0.34955413356423376, 3.0566021317077466e-39] 0.17477706678211688
# Npfcan_drminsv npf 5
# [-0.3368783989548683, 3.0566021317077466e-39] 0.16843919947743416
# Npfcan_drminsv npf 6
# [-0.32462359488010406, 3.0566021317077466e-39] 0.16231179744005203
# Npfcan_drminsv npf 7
# [-0.3122194018959999, 3.0566021317077466e-39] 0.15610970094799995
# Npfcan_drminsv npf 8
# [-0.30029380843043324, 3.0566021317077466e-39] 0.15014690421521662
# Npfcan_drminsv npf 9
# [-0.2886387424170971, 3.0566021317077466e-39] 0.14431937120854854
# Npfcan_drminsv npf 10
# [-0.27827195286750794, 3.0566021317077466e-39] 0.13913597643375397
# Npfcan_drminsv npf 11
# [-0.26794238984584806, 3.0566021317077466e-39] 0.13397119492292403
# Npfcan_drminsv npf 12
# [-0.2598145692050457, 3.0566021317077466e-39] 0.12990728460252285
# Npfcan_drminsv npf 13
# [-0.25300253823399543, 3.0566021317077466e-39] 0.12650126911699772
# Npfcan_drminsv npf 14
# [-0.24780932061374186, 3.05664985292695e-39] 0.12390466030687093
# Npfcan_drminsv npf 15
# [-0.24350142307579517, 3.05664985292695e-39] 0.12175071153789759
# Npfcan_drminsv npf 16
# [-0.2400377286225557, 3.05664985292695e-39] 0.12001886431127785
# Npfcan_drminsv npf 17
# [-0.2374833310395479, 3.05664985292695e-39] 0.11874166551977396
# Npfcan_drminsv npf 18
# [-0.235914081633091, 3.05664985292695e-39] 0.1179570408165455
# Npfcan_drminsv npf 19
# [-0.2349466445297003, 3.05664985292695e-39] 0.11747332226485015
# Npfcan_drminsv npf 20
# [-0.23431676514446736, 3.05664985292695e-39] 0.11715838257223368
# Npfcan_drminsv npf 21
# [-0.23399175740778444, 3.05664985292695e-39] 0.11699587870389222
# Npfcan_drminsv npf 22
# [-0.23371168099343775, 3.05664985292695e-39] 0.11685584049671888
# Npfcan_drminsv npf 23
# [-0.23364634618163108, 3.05664985292695e-39] 0.11682317309081554
# Npfcan_drminsv npf 24
# [-0.23351096779108046, 3.05664985292695e-39] 0.11675548389554023
# Npfcan_puppiw npf 0
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 1
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 2
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 3
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 4
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 5
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 6
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 7
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 8
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 9
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 10
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 11
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 12
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 13
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 14
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 15
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 16
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 17
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 18
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 19
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 20
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 21
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 22
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 23
# [0.0, 1.0] 0.5
# Npfcan_puppiw npf 24
# [0.0, 1.0] 0.5

# %%
vtx_epsilons = np.zeros((len(vtx_branches),4))

# %%
vtx_ranges = np.zeros((len(vtx_branches),4, 2))

# %%
for (i,key) in enumerate(vtx_branches):
    for cand in range(4):
        range_inputs = quantile_min_max(key,'vtx',cand)
        scale_epsilon = (range_inputs[1] - range_inputs[0])/2
        vtx_epsilons[i,cand] = scale_epsilon
        vtx_ranges[i,cand] = range_inputs
        print(range_inputs, scale_epsilon)
# Out:
# sv_pt vtx 0
# [0.0, 367.76021011352543] 183.88010505676272
# sv_pt vtx 1
# [0.0, 377.9374073791506] 188.9687036895753
# sv_pt vtx 2
# [0.0, 381.6216246032718] 190.8108123016359
# sv_pt vtx 3
# [0.0, 382.3482508850098] 191.1741254425049
# sv_deltaR vtx 0
# [-0.49756693974137306, 1.0] 0.7487834698706866
# sv_deltaR vtx 1
# [-0.49766344025731085, 1.0] 0.7488317201286554
# sv_deltaR vtx 2
# [-0.4976642429828644, 1.0] 0.7488321214914322
# sv_deltaR vtx 3
# [-0.49766804441809653, 1.0] 0.7488340222090483
# sv_mass vtx 0
# [0.0, 12.982587194442777] 6.4912935972213885
# sv_mass vtx 1
# [0.0, 15.283788576126113] 7.641894288063057
# sv_mass vtx 2
# [0.0, 15.98883020401004] 7.99441510200502
# sv_mass vtx 3
# [0.0, 16.232963218688976] 8.116481609344488
# sv_ntracks vtx 0
# [0.0, 9.0] 4.5
# sv_ntracks vtx 1
# [0.0, 10.0] 5.0
# sv_ntracks vtx 2
# [0.0, 10.0] 5.0
# sv_ntracks vtx 3
# [0.0, 10.0] 5.0
# sv_chi2 vtx 0
# [0.0, 14.645934300422669] 7.322967150211334
# sv_chi2 vtx 1
# [0.0, 15.159636454582223] 7.579818227291112
# sv_chi2 vtx 2
# [0.0, 15.359875984191907] 7.679937992095954
# sv_chi2 vtx 3
# [0.0, 15.499616413116462] 7.749808206558231
# sv_normchi2 vtx 0
# [0.0, 7.825212893486026] 3.912606446743013
# sv_normchi2 vtx 1
# [0.0, 7.658508913517007] 3.8292544567585036
# sv_normchi2 vtx 2
# [0.0, 7.498962345123292] 3.749481172561646
# sv_normchi2 vtx 3
# [0.0, 7.426820895671845] 3.7134104478359227
# sv_dxy vtx 0
# [0.0, 15.84480495452881] 7.922402477264405
# sv_dxy vtx 1
# [0.0, 11.132235627174381] 5.566117813587191
# sv_dxy vtx 2
# [0.0, 10.57260735511781] 5.286303677558905
# sv_dxy vtx 3
# [0.0, 9.902901430130008] 4.951450715065004
# sv_dxysig vtx 0
# [0.0, 388.43463867187523] 194.21731933593762
# sv_dxysig vtx 1
# [0.0, 173.1046592712408] 86.5523296356204
# sv_dxysig vtx 2
# [0.0, 152.92120140075698] 76.46060070037849
# sv_dxysig vtx 3
# [0.0, 150.44026428222665] 75.22013214111333
# sv_d3d vtx 0
# [0.0, 24.122535886764595] 12.061267943382298
# sv_d3d vtx 1
# [0.0, 17.525023021698004] 8.762511510849002
# sv_d3d vtx 2
# [0.0, 16.03488545417787] 8.017442727088936
# sv_d3d vtx 3
# [0.0, 15.548072795867942] 7.774036397933971
# sv_d3dsig vtx 0
# [0.0, 389.5174772644055] 194.75873863220275
# sv_d3dsig vtx 1
# [0.0, 173.4268005371099] 86.71340026855495
# sv_d3dsig vtx 2
# [0.0, 153.19877639770507] 76.59938819885254
# sv_d3dsig vtx 3
# [0.0, 150.84338058471693] 75.42169029235846
# sv_costhetasvpv vtx 0
# [-0.9241633626818657, 1.0] 0.9620816813409329
# sv_costhetasvpv vtx 1
# [-0.9895075473189354, 1.0] 0.9947537736594677
# sv_costhetasvpv vtx 2
# [-0.9929883381724357, 1.0] 0.9964941690862179
# sv_costhetasvpv vtx 3
# [-0.9936783090233803, 1.0] 0.9968391545116901
# sv_enratio vtx 0
# [0.0, 1.0] 0.5
# sv_enratio vtx 1
# [0.0, 1.0] 0.5
# sv_enratio vtx 2
# [0.0, 1.0] 0.5
# sv_enratio vtx 3
# [0.0, 1.0] 0.5

# %%
np.save('/eos/user/a/anstein/public/DeepJet/Train_DF_Run2/auxiliary/global_epsilons.npy',global_epsilons)

# %%
np.save('/eos/user/a/anstein/public/DeepJet/Train_DF_Run2/auxiliary/global_ranges.npy',global_ranges)

# %%
np.save('/eos/user/a/anstein/public/DeepJet/Train_DF_Run2/auxiliary/cpf_epsilons.npy',cpf_epsilons)

# %%
np.save('/eos/user/a/anstein/public/DeepJet/Train_DF_Run2/auxiliary/cpf_ranges.npy',cpf_ranges)

# %%
np.save('/eos/user/a/anstein/public/DeepJet/Train_DF_Run2/auxiliary/npf_epsilons.npy',npf_epsilons)

# %%
np.save('/eos/user/a/anstein/public/DeepJet/Train_DF_Run2/auxiliary/npf_ranges.npy',npf_ranges)

# %%
np.save('/eos/user/a/anstein/public/DeepJet/Train_DF_Run2/auxiliary/vtx_epsilons.npy',vtx_epsilons)

# %%
np.save('/eos/user/a/anstein/public/DeepJet/Train_DF_Run2/auxiliary/vtx_ranges.npy',vtx_ranges)
