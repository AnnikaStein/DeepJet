# %% [markdown]
# # ROC curves
# ## Comparison of different trainings with different setups for inference

# %%
import numpy as np

import matplotlib.pyplot as plt
import mplhep as hep


plt.style.use(hep.cms.style.ROOT)

# %%
plt.rcParams['axes.axisbelow'] = True

# %%
#model_names = ['nominal', 'adversarial_eps0p01', 'adversarial_eps0p005']
#model_names = ['testADV3']
#model_names = ['testNOM','testADV3']
#model_names = ['NOM_FLgamma2','testADVNGM']
#model_names = ['testNOM','testADVNGM']
model_names = ['testNGMPUPPI']
#prediction_setups = ['_20','_20_NGM','_20_FGSM']
#prediction_setups = ['_ttbar_20']
#prediction_setups = ['_ttbar_20','_ttbar_20_NGM','_ttbar_20_FGSM']
prediction_setups = ['_ttbar_8','_qcd_8','_ttbar_10','_qcd_10']#,'_ttbar_best_NGM_002_noRestrict','_ttbar_best_FGSM_NEW']
prediction_files = 'outfiles'

# %%
tagger = 'ParT' # 'DF'

# %%
dirz = [[f'/eos/user/a/anstein/{tagger}/{model_name}/predict{prediction_setup}/' \
        for model_name in model_names] for prediction_setup in prediction_setups]

# %%
dirz
# Out:
# [['/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_8/'],
#  ['/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_8/'],
#  ['/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_10/'],
#  ['/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_10/']]

# %%
dirz[0][0] = '/e'+dirz[0][0].strip('predict/')+'/predict_ttbar_10/'
#dirz[1][0] = '/e'+dirz[1][0].strip('predict_FGSM/')+'/predict_FGSM_NEW/'

# %%
dirz
# Out:
# [['/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_8/predict_NEW/']]

# %%
NEW_BvsL_paths = [item + f'BvL_{prediction_files}_NEW.npy' for sublist in dirz for item in sublist]

# %%
NEW_BvsL_paths
# Out:
# ['/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_8/BvL_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_8/BvL_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_10/BvL_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_10/BvL_outfiles_NEW.npy']

# %%
NEW_CvsB_paths = [item + f'CvB_{prediction_files}_NEW.npy' for sublist in dirz for item in sublist]

# %%
NEW_CvsB_paths
# Out:
# ['/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_8/CvB_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_8/CvB_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_10/CvB_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_10/CvB_outfiles_NEW.npy']

# %%
NEW_CvsL_paths = [item + f'CvL_{prediction_files}_NEW.npy' for sublist in dirz for item in sublist]

# %%
NEW_CvsL_paths
# Out:
# ['/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_8/CvL_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_8/CvL_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_10/CvL_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_10/CvL_outfiles_NEW.npy']

# %%
NEW_BvsC_paths = [item + f'BvC_{prediction_files}_NEW.npy' for sublist in dirz for item in sublist]

# %%
NEW_BvsC_paths
# Out:
# ['/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_8/BvC_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_8/BvC_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_ttbar_10/BvC_outfiles_NEW.npy',
#  '/eos/user/a/anstein/ParT/testNGMPUPPI/predict_qcd_10/BvC_outfiles_NEW.npy']

# %% [markdown]
# # NEW

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-4)
ax.set_ylim(top=1)

tag_name = ' (b,bb,lepb)'
mistag_name = ' (uds,g)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

#linestyles = ['-','-','--','--']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
#linestyles = ['-','--','--']
#colors = ['tab:blue','tab:orange','tab:green']
#linestyles = ['-','-']
#colors = ['tab:blue','tab:orange']
#linestyles = ['-','--','-','--','-','--']
#colors = ['tab:blue','tab:blue','tab:orange','tab:orange','tab:green','tab:green']
#linestyles = ['-','-','--','--',':',':']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange','tab:blue','tab:orange']
linestyles = ['-','--','-','--']
colors = ['tab:purple','tab:purple','tab:green','tab:green']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs', r'adversarial inputs']
#names_models = [r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5']
#names_setups = ['nominal inputs',r'NGM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs',r'nominal inputs']
#names_models = ['Nominal training', r'Adversarial training','Nominal training', r'Adversarial training','Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs','nominal inputs',r'NGM inputs ($\epsilon=0.02$)',r'NGM inputs ($\epsilon=0.02$)',r'FGSM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
names_models = [r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T$',
                r'QCD events, $300$ GeV $<$ jet $p_T$',
                r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T$',
                r'QCD events, $300$ GeV $<$ jet $p_T$']
names_setups = ['Epoch 8','Epoch 8','Epoch 10','Epoch 10']
legtitle = 'BvsL'
legloc = 'upper left'
#for i in range(4):
#for i in range(3):
#for i in range(2):
#for i in range(6):
#for i in range(1):
for i in range(4):
    xya = np.load(NEW_BvsL_paths[i], allow_pickle=True)
    #legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
#    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
#leg = ax.legend(title='RobustParT '+legtitle + ' Nominal inputs' + '\n' + r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
leg = ax.legend(title='RobustParT '+legtitle + ' - Nominal inputs' + '\n' + r'jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='13.6 TeV')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.pdf', bbox_inches='tight')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.png', bbox_inches='tight', dpi=900, facecolor='w', transparent=False)
# Out:
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-4)
ax.set_ylim(top=1)

tag_name = ' (b,bb,lepb)'
mistag_name = ' (c)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

#linestyles = ['-','-','--','--']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
#linestyles = ['-','--','--']
#colors = ['tab:blue','tab:orange','tab:green']
#linestyles = ['-','-']
#colors = ['tab:blue','tab:orange']
#linestyles = ['-','--','-','--','-','--']
#colors = ['tab:blue','tab:blue','tab:orange','tab:orange','tab:green','tab:green']
#linestyles = ['-','-','--','--',':',':']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange','tab:blue','tab:orange']
linestyles = ['-','--','-','--']
colors = ['tab:purple','tab:purple','tab:green','tab:green']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs', r'adversarial inputs']
#names_models = [r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5']
#names_setups = ['nominal inputs',r'NGM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs',r'nominal inputs']
#names_models = ['Nominal training', r'Adversarial training','Nominal training', r'Adversarial training','Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs','nominal inputs',r'NGM inputs ($\epsilon=0.02$)',r'NGM inputs ($\epsilon=0.02$)',r'FGSM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
names_models = [r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T$',
                r'QCD events, $300$ GeV $<$ jet $p_T$',
                r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T$',
                r'QCD events, $300$ GeV $<$ jet $p_T$']
names_setups = ['Epoch 8','Epoch 8','Epoch 10','Epoch 10']
legtitle = 'BvsC'
legloc = 'upper left'
#for i in range(4):
#for i in range(3):
#for i in range(2):
#for i in range(6):
#for i in range(1):
for i in range(4):
    xya = np.load(NEW_BvsC_paths[i], allow_pickle=True)
    #legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
#    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
#leg = ax.legend(title='RobustParT '+legtitle + ' Nominal inputs' + '\n' + r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
leg = ax.legend(title='RobustParT '+legtitle + ' - Nominal inputs' + '\n' + r'jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='13.6 TeV')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.pdf', bbox_inches='tight')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.png', bbox_inches='tight', dpi=900, facecolor='w', transparent=False)
# Out:
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-4)
ax.set_ylim(top=1)

tag_name = ' (c)'
mistag_name = ' (b,bb,lepb)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

#linestyles = ['-','-','--','--']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
#linestyles = ['-','--','--']
#colors = ['tab:blue','tab:orange','tab:green']
#linestyles = ['-','-']
#colors = ['tab:blue','tab:orange']
#linestyles = ['-','--','-','--','-','--']
#colors = ['tab:blue','tab:blue','tab:orange','tab:orange','tab:green','tab:green']
#linestyles = ['-','-','--','--',':',':']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange','tab:blue','tab:orange']
linestyles = ['-','--','-','--']
colors = ['tab:purple','tab:purple','tab:green','tab:green']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs', r'adversarial inputs']
#names_models = [r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5']
#names_setups = ['nominal inputs',r'NGM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs',r'nominal inputs']
#names_models = ['Nominal training', r'Adversarial training','Nominal training', r'Adversarial training','Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs','nominal inputs',r'NGM inputs ($\epsilon=0.02$)',r'NGM inputs ($\epsilon=0.02$)',r'FGSM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
names_models = [r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T$',
                r'QCD events, $300$ GeV $<$ jet $p_T$',
                r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T$',
                r'QCD events, $300$ GeV $<$ jet $p_T$']
names_setups = ['Epoch 8','Epoch 8','Epoch 10','Epoch 10']
legtitle = 'CvsB'
legloc = 'lower right'
#for i in range(4):
#for i in range(3):
#for i in range(2):
#for i in range(6):
#for i in range(1):
for i in range(4):
    xya = np.load(NEW_CvsB_paths[i], allow_pickle=True)
    #legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
#    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
#leg = ax.legend(title='RobustParT '+legtitle + ' Nominal inputs' + '\n' + r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
leg = ax.legend(title='RobustParT '+legtitle + ' - Nominal inputs' + '\n' + r'jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='13.6 TeV')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.pdf', bbox_inches='tight')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.png', bbox_inches='tight', dpi=900, facecolor='w', transparent=False)
# Out:
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-4)
ax.set_ylim(top=1)

tag_name = ' (c)'
mistag_name = ' (uds,g)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

#linestyles = ['-','-','--','--']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
#linestyles = ['-','--','--']
#colors = ['tab:blue','tab:orange','tab:green']
#linestyles = ['-','-']
#colors = ['tab:blue','tab:orange']
#linestyles = ['-','--','-','--','-','--']
#colors = ['tab:blue','tab:blue','tab:orange','tab:orange','tab:green','tab:green']
#linestyles = ['-','-','--','--',':',':']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange','tab:blue','tab:orange']
linestyles = ['-','--','-','--']
colors = ['tab:purple','tab:purple','tab:green','tab:green']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs', r'adversarial inputs']
#names_models = [r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5']
#names_setups = ['nominal inputs',r'NGM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs',r'nominal inputs']
#names_models = ['Nominal training', r'Adversarial training','Nominal training', r'Adversarial training','Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs','nominal inputs',r'NGM inputs ($\epsilon=0.02$)',r'NGM inputs ($\epsilon=0.02$)',r'FGSM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
names_models = [r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T$',
                r'QCD events, $300$ GeV $<$ jet $p_T$',
                r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T$',
                r'QCD events, $300$ GeV $<$ jet $p_T$']
names_setups = ['Epoch 8','Epoch 8','Epoch 10','Epoch 10']
legtitle = 'CvsL'
legloc = 'lower right'
#for i in range(4):
#for i in range(3):
#for i in range(2):
#for i in range(6):
#for i in range(1):
for i in range(4):
    xya = np.load(NEW_CvsL_paths[i], allow_pickle=True)
    #legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
#    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
#leg = ax.legend(title='RobustParT '+legtitle + ' Nominal inputs' + '\n' + r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
leg = ax.legend(title='RobustParT '+legtitle + ' - Nominal inputs' + '\n' + r'jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='13.6 TeV')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.pdf', bbox_inches='tight')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.png', bbox_inches='tight', dpi=900, facecolor='w', transparent=False)
# Out:
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-4)
ax.set_ylim(top=1)

tag_name = ' (b,bb,lepb)'
mistag_name = ' (uds,g)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

#linestyles = ['-','-','--','--']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
#linestyles = ['-','--','--']
#colors = ['tab:blue','tab:orange','tab:green']
#linestyles = ['-','-']
#colors = ['tab:blue','tab:orange']
#linestyles = ['-','--','-','--','-','--']
#colors = ['tab:blue','tab:blue','tab:orange','tab:orange','tab:green','tab:green']
#linestyles = ['-','-','--','--',':',':']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange','tab:blue','tab:orange']
linestyles = ['-']
colors = ['tab:orange']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs', r'adversarial inputs']
#names_models = [r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5']
#names_setups = ['nominal inputs',r'NGM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs',r'nominal inputs']
#names_models = ['Nominal training', r'Adversarial training','Nominal training', r'Adversarial training','Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs','nominal inputs',r'NGM inputs ($\epsilon=0.02$)',r'NGM inputs ($\epsilon=0.02$)',r'FGSM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
names_models = [r'Adversarial training']
names_setups = ['nominal inputs']
legtitle = 'BvsL'
legloc = 'upper left'
#for i in range(4):
#for i in range(3):
#for i in range(2):
#for i in range(6):
for i in range(1):
    xya = np.load(NEW_BvsC_paths[i], allow_pickle=True)
    #legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
leg = ax.legend(title='RobustParT '+legtitle + '\n' + r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='13.6 TeV')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbar_8_ROC.pdf', bbox_inches='tight')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbar_8_ROC.png', bbox_inches='tight', dpi=900, facecolor='w', transparent=False)

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-4)
ax.set_ylim(top=1)

tag_name = ' (b,bb,lepb)'
mistag_name = ' (c)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

#linestyles = ['-','-','--','--']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
#linestyles = ['-','--','--']
#colors = ['tab:blue','tab:orange','tab:green']
#linestyles = ['-','-']
#colors = ['tab:blue','tab:orange']
#linestyles = ['-','--','-','--','-','--']
#colors = ['tab:blue','tab:blue','tab:orange','tab:orange','tab:green','tab:green']
#linestyles = ['-','-','--','--',':',':']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange','tab:blue','tab:orange']
linestyles = ['-']
colors = ['tab:orange']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs', r'adversarial inputs']
#names_models = [r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5']
#names_setups = ['nominal inputs',r'NGM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs',r'nominal inputs']
#names_models = ['Nominal training', r'Adversarial training','Nominal training', r'Adversarial training','Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs','nominal inputs',r'NGM inputs ($\epsilon=0.02$)',r'NGM inputs ($\epsilon=0.02$)',r'FGSM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
names_models = [r'Adversarial training']
names_setups = ['nominal inputs']
legtitle = 'BvsC'
legloc = 'upper left'
#for i in range(4):
#for i in range(3):
#for i in range(2):
#for i in range(6):
for i in range(1):
    xya = np.load(NEW_BvsC_paths[i], allow_pickle=True)
    #legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
leg = ax.legend(title='RobustParT '+legtitle + '\n' + r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='13.6 TeV')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.pdf', bbox_inches='tight')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.png', bbox_inches='tight', dpi=900, facecolor='w', transparent=False)
# Out:
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-4)
ax.set_ylim(top=1)

tag_name = ' (c)'
mistag_name = ' (b,bb,lepb)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

#linestyles = ['-','-','--','--']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
#linestyles = ['-','--','--']
#colors = ['tab:blue','tab:orange','tab:green']
#linestyles = ['-','-']
#colors = ['tab:blue','tab:orange']
#linestyles = ['-','--','-','--','-','--']
#colors = ['tab:blue','tab:blue','tab:orange','tab:orange','tab:green','tab:green']
#linestyles = ['-','-','--','--',':',':']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange','tab:blue','tab:orange']
linestyles = ['-']
colors = ['tab:orange']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs', r'adversarial inputs']
#names_models = [r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5']
#names_setups = ['nominal inputs',r'NGM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs',r'nominal inputs']
#names_models = ['Nominal training', r'Adversarial training','Nominal training', r'Adversarial training','Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs','nominal inputs',r'NGM inputs ($\epsilon=0.02$)',r'NGM inputs ($\epsilon=0.02$)',r'FGSM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
names_models = [r'Adversarial training']
names_setups = ['nominal inputs']
legtitle = 'CvsB'
legloc = 'upper left'
#for i in range(4):
#for i in range(3):
#for i in range(2):
#for i in range(6):
for i in range(1):
    xya = np.load(NEW_CvsB_paths[i], allow_pickle=True)
    #legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
leg = ax.legend(title='RobustParT '+legtitle + '\n' + r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='13.6 TeV')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.pdf', bbox_inches='tight')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.png', bbox_inches='tight', dpi=900, facecolor='w', transparent=False)
# Out:
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-4)
ax.set_ylim(top=1)

tag_name = ' (c)'
mistag_name = ' (uds,g)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

#linestyles = ['-','-','--','--']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
#linestyles = ['-','--','--']
#colors = ['tab:blue','tab:orange','tab:green']
#linestyles = ['-','-']
#colors = ['tab:blue','tab:orange']
#linestyles = ['-','--','-','--','-','--']
#colors = ['tab:blue','tab:blue','tab:orange','tab:orange','tab:green','tab:green']
#linestyles = ['-','-','--','--',':',':']
#colors = ['tab:blue','tab:orange','tab:blue','tab:orange','tab:blue','tab:orange']
linestyles = ['-']
colors = ['tab:orange']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs', r'adversarial inputs']
#names_models = [r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5',r'Nom x 10 + NGM x 5 + NGM & FL x 5']
#names_setups = ['nominal inputs',r'NGM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
#names_models = ['Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs',r'nominal inputs']
#names_models = ['Nominal training', r'Adversarial training','Nominal training', r'Adversarial training','Nominal training', r'Adversarial training']
#names_setups = ['nominal inputs','nominal inputs',r'NGM inputs ($\epsilon=0.02$)',r'NGM inputs ($\epsilon=0.02$)',r'FGSM inputs ($\epsilon=0.01$)',r'FGSM inputs ($\epsilon=0.01$)']
names_models = [r'Adversarial training']
names_setups = ['nominal inputs']
legtitle = 'CvsL'
legloc = 'upper left'
#for i in range(4):
#for i in range(3):
#for i in range(2):
#for i in range(6):
for i in range(1):
    xya = np.load(NEW_CvsL_paths[i], allow_pickle=True)
    #legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
    legend_text = names_models[i] + '\n' + (names_setups[i]) + '\n' + 'AUC = ' + f'{xya[2]:.4f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
leg = ax.legend(title='ParT '+legtitle + '\n' + r'$t\bar{t}$ events, $30$ GeV $<$ jet $p_T < 1000$ GeV, |jet $\eta| < 2.5$',loc=legloc,fontsize=14,title_fontsize=18,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='13.6 TeV')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.pdf', bbox_inches='tight')
fig.savefig(legtitle + '_' + tagger + '_NGMPUPPI_ttbarQCD_8_10_ROC.png', bbox_inches='tight', dpi=900, facecolor='w', transparent=False)
# Out:
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
